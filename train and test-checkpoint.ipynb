# %%
import numpy as np
import cv2

from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D
from keras.optimizers import Adam
from keras.layers import MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator

# %%
train_dir = 'data/train'
val_dir = 'data/test'
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(120,120),
        batch_size=64,
        color_mode="rgb",
        class_mode='categorical')
validation_generator = val_datagen.flow_from_directory(
        val_dir,
        target_size=(120,120),
        batch_size=64,
        color_mode="rgb",
        class_mode='categorical')
# Out:
# Found 2700 images belonging to 2 classes.
# Found 2700 images belonging to 2 classes.

# %%
models = Sequential()

models.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(120,120,3)))
models.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
models.add(MaxPooling2D(pool_size=(2, 2)))
models.add(Dropout(0.25))

models.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
models.add(MaxPooling2D(pool_size=(2, 2)))
models.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
models.add(MaxPooling2D(pool_size=(2, 2)))
models.add(Dropout(0.25))

models.add(Flatten())
models.add(Dense(1024, activation='relu'))
models.add(Dropout(0.5))
models.add(Dense(2, activation='softmax'))

# %%
models.compile(loss='categorical_crossentropy',optimizer=Adam(lr=0.0001, decay=1e-6),metrics=['accuracy'])

models_info = models.fit_generator(
        train_generator,
        steps_per_epoch=1800 // 64,
        epochs=40,
        validation_data=validation_generator,
        validation_steps=1800 // 64)
# Out:
# WARNING:tensorflow:From <ipython-input-5-94d5cadc5f2c>:3: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/40
# 28/28 [==============================] - 388s 14s/step - loss: 0.6951 - accuracy: 0.6241 - val_loss: 0.6602 - val_accuracy: 0.6618
# Epoch 2/40
# 28/28 [==============================] - 381s 14s/step - loss: 0.6298 - accuracy: 0.6661 - val_loss: 0.6337 - val_accuracy: 0.6629
# Epoch 3/40
# 28/28 [==============================] - 405s 14s/step - loss: 0.6104 - accuracy: 0.6680 - val_loss: 0.6239 - val_accuracy: 0.6685
# Epoch 4/40
# 28/28 [==============================] - 401s 14s/step - loss: 0.6008 - accuracy: 0.6529 - val_loss: 0.5962 - val_accuracy: 0.6680
# Epoch 5/40
# 28/28 [==============================] - 395s 14s/step - loss: 0.5902 - accuracy: 0.6569 - val_loss: 0.6038 - val_accuracy: 0.6557
# Epoch 6/40
# 28/28 [==============================] - 394s 14s/step - loss: 0.5948 - accuracy: 0.6678 - val_loss: 0.5790 - val_accuracy: 0.6741
# Epoch 7/40
# 28/28 [==============================] - 406s 14s/step - loss: 0.5685 - accuracy: 0.6718 - val_loss: 0.5870 - val_accuracy: 0.6624
# Epoch 8/40
# 28/28 [==============================] - 397s 14s/step - loss: 0.5773 - accuracy: 0.6649 - val_loss: 0.5933 - val_accuracy: 0.6641
# Epoch 9/40
# 28/28 [==============================] - 395s 14s/step - loss: 0.5715 - accuracy: 0.6621 - val_loss: 0.6167 - val_accuracy: 0.6512
# Epoch 10/40
# 28/28 [==============================] - 407s 15s/step - loss: 0.5827 - accuracy: 0.6775 - val_loss: 0.5899 - val_accuracy: 0.6763
# Epoch 11/40
# 28/28 [==============================] - 383s 14s/step - loss: 0.5754 - accuracy: 0.6635 - val_loss: 0.5715 - val_accuracy: 0.6780
# Epoch 12/40
# 28/28 [==============================] - 396s 14s/step - loss: 0.5763 - accuracy: 0.6443 - val_loss: 0.5826 - val_accuracy: 0.6669
# Epoch 13/40
# 28/28 [==============================] - 449s 16s/step - loss: 0.5629 - accuracy: 0.6719 - val_loss: 0.5601 - val_accuracy: 0.6719
# Epoch 14/40
# 28/28 [==============================] - 449s 16s/step - loss: 0.5685 - accuracy: 0.6635 - val_loss: 0.5553 - val_accuracy: 0.6669
# Epoch 15/40
# 28/28 [==============================] - 434s 16s/step - loss: 0.5673 - accuracy: 0.6638 - val_loss: 0.5498 - val_accuracy: 0.6747
# Epoch 16/40
# 28/28 [==============================] - 445s 16s/step - loss: 0.5670 - accuracy: 0.6618 - val_loss: 0.5634 - val_accuracy: 0.6691
# Epoch 17/40
# 28/28 [==============================] - 447s 16s/step - loss: 0.5640 - accuracy: 0.6609 - val_loss: 0.5602 - val_accuracy: 0.6708
# Epoch 18/40
# 28/28 [==============================] - 443s 16s/step - loss: 0.5520 - accuracy: 0.6685 - val_loss: 0.5405 - val_accuracy: 0.6808
# Epoch 19/40
# 28/28 [==============================] - 442s 16s/step - loss: 0.5669 - accuracy: 0.6540 - val_loss: 0.5683 - val_accuracy: 0.6574
# Epoch 20/40
# 28/28 [==============================] - 434s 16s/step - loss: 0.5517 - accuracy: 0.6569 - val_loss: 0.5443 - val_accuracy: 0.6624
# Epoch 21/40
# 28/28 [==============================] - 428s 15s/step - loss: 0.5466 - accuracy: 0.6626 - val_loss: 0.5549 - val_accuracy: 0.6674
# Epoch 22/40
# 28/28 [==============================] - 428s 15s/step - loss: 0.5465 - accuracy: 0.6661 - val_loss: 0.5376 - val_accuracy: 0.6802
# Epoch 23/40
# 28/28 [==============================] - 435s 16s/step - loss: 0.5499 - accuracy: 0.6517 - val_loss: 0.5442 - val_accuracy: 0.6635
# Epoch 24/40
# 28/28 [==============================] - 441s 16s/step - loss: 0.5609 - accuracy: 0.6529 - val_loss: 0.5458 - val_accuracy: 0.6641
# Epoch 25/40
# 28/28 [==============================] - 444s 16s/step - loss: 0.5545 - accuracy: 0.6362 - val_loss: 0.5423 - val_accuracy: 0.6607
# Epoch 26/40
# 28/28 [==============================] - 451s 16s/step - loss: 0.5450 - accuracy: 0.6579 - val_loss: 0.5341 - val_accuracy: 0.6624
# Epoch 27/40
# 28/28 [==============================] - 439s 16s/step - loss: 0.5496 - accuracy: 0.6517 - val_loss: 0.5412 - val_accuracy: 0.6696
# Epoch 28/40
# 28/28 [==============================] - 444s 16s/step - loss: 0.5450 - accuracy: 0.6468 - val_loss: 0.5319 - val_accuracy: 0.6713
# Epoch 29/40
# 28/28 [==============================] - 437s 16s/step - loss: 0.5519 - accuracy: 0.6603 - val_loss: 0.5894 - val_accuracy: 0.6747
# Epoch 30/40
# 28/28 [==============================] - 431s 15s/step - loss: 0.5365 - accuracy: 0.6575 - val_loss: 0.5339 - val_accuracy: 0.6702
# Epoch 31/40
# 28/28 [==============================] - 426s 15s/step - loss: 0.5378 - accuracy: 0.6592 - val_loss: 0.5412 - val_accuracy: 0.6596
# Epoch 32/40
# 28/28 [==============================] - 440s 16s/step - loss: 0.5414 - accuracy: 0.6429 - val_loss: 0.5382 - val_accuracy: 0.6674
# Epoch 33/40
# 28/28 [==============================] - 440s 16s/step - loss: 0.5374 - accuracy: 0.6672 - val_loss: 0.5301 - val_accuracy: 0.6685
# Epoch 34/40
# 28/28 [==============================] - 427s 15s/step - loss: 0.5306 - accuracy: 0.6672 - val_loss: 0.5367 - val_accuracy: 0.6535
# Epoch 35/40
# 28/28 [==============================] - 442s 16s/step - loss: 0.5302 - accuracy: 0.6680 - val_loss: 0.5425 - val_accuracy: 0.6691
# Epoch 36/40
# 28/28 [==============================] - 434s 15s/step - loss: 0.5317 - accuracy: 0.6661 - val_loss: 0.5287 - val_accuracy: 0.6635
# Epoch 37/40
# 28/28 [==============================] - 432s 15s/step - loss: 0.5297 - accuracy: 0.6695 - val_loss: 0.5143 - val_accuracy: 0.6780
# Epoch 38/40
# 28/28 [==============================] - 444s 16s/step - loss: 0.5333 - accuracy: 0.6494 - val_loss: 0.5303 - val_accuracy: 0.6780
# Epoch 39/40
# 28/28 [==============================] - 448s 16s/step - loss: 0.5230 - accuracy: 0.6585 - val_loss: 0.5237 - val_accuracy: 0.6624
# Epoch 40/40
# 28/28 [==============================] - 446s 16s/step - loss: 0.5256 - accuracy: 0.6579 - val_loss: 0.5163 - val_accuracy: 0.6702

# %%
models.save_weights('model.h5')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(models_info.history['loss'])
plt.plot(models_info.history['val_loss'])
plt.title('Models Training and Validation loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()

# %%
plt.plot(models_info.history['accuracy'])
plt.plot(models_info.history['val_accuracy'])
plt.title('Models Training and Validation loss')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='lower right')
plt.show()
